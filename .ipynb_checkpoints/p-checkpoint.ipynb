# %%
import datapane as dp
import pandas as pd
from pytrends.request import TrendReq
import altair as alt

pytrends = TrendReq(hl='en-US', tz=360)
dp.Params.load_defaults('datapane.yaml')
kw_list = dp.Params.get('query', 'donald trump')

# %%
pytrends.build_payload([kw_list], cat=0, timeframe='today 5-y', geo='US', gprop='')

# %%
r_o_t = pytrends.interest_over_time().reset_index()

# %%
regions = pytrends.interest_by_region(resolution='REGION', inc_geo_code=True)

# %%
geo = regions[regions[kw_list] > 0].reset_index()

# %%
r_o_t_plot = alt.Chart(r_o_t).encode(x='date', y=kw_list).mark_line(width=0.5).interactive()

# %%
geo_query
# Out:
#            lon        lat           state            city         geoName  \
# 0   -86.279118  32.361538         Alabama      Montgomery         Alabama
# 1  -134.419740  58.301935          Alaska          Juneau          Alaska
# 2  -112.073844  33.448457         Arizona         Phoenix         Arizona
# 3   -92.331122  34.736009        Arkansas     Little Rock        Arkansas
# 4  -121.468926  38.555605      California      Sacramento      California
# 5  -104.984167  39.739167        Colorado          Denver        Colorado
# 6   -72.677000  41.767000     Connecticut        Hartford     Connecticut
# 7   -75.526755  39.161921        Delaware           Dover        Delaware
# 8   -84.272770  30.451800         Florida     Tallahassee         Florida
# 9   -84.390000  33.760000         Georgia         Atlanta         Georgia
# 10 -157.826182  21.308950          Hawaii        Honolulu          Hawaii
# 11 -116.237651  43.613739           Idaho           Boise           Idaho
# 12  -89.650373  39.783250        Illinois     Springfield        Illinois
# 13  -86.147685  39.790942         Indiana    Indianapolis         Indiana
# 14  -93.620866  41.590939            Iowa      Des Moines            Iowa
# 15  -95.690000  39.040000          Kansas          Topeka          Kansas
# 16  -84.863110  38.197274        Kentucky       Frankfort        Kentucky
# 17  -91.140229  30.458090       Louisiana     Baton Rouge       Louisiana
# 18  -69.765261  44.323535           Maine         Augusta           Maine
# 19  -76.501157  38.972945        Maryland       Annapolis        Maryland
# 20  -71.027500  42.235200   Massachusetts          Boston   Massachusetts
# 21  -84.546700  42.733500        Michigan         Lansing        Michigan
# 22  -93.094000  44.950000       Minnesota      Saint Paul       Minnesota
# 23  -90.207000  32.320000     Mississippi         Jackson     Mississippi
# 24  -92.189283  38.572954        Missouri  Jefferson City        Missouri
# 25 -112.027031  46.595805         Montana          Helena         Montana
# 26  -96.675345  40.809868        Nebraska         Lincoln        Nebraska
# 27 -119.753877  39.160949          Nevada     Carson City          Nevada
# 28  -71.549127  43.220093   New Hampshire         Concord   New Hampshire
# 29  -74.756138  40.221741      New Jersey         Trenton      New Jersey
# 30 -105.964575  35.667231      New Mexico        Santa Fe      New Mexico
# 31  -73.781339  42.659829        New York          Albany        New York
# 32  -78.638000  35.771000  North Carolina         Raleigh  North Carolina
# 33 -100.779004  48.813343    North Dakota        Bismarck    North Dakota
# 34  -83.000647  39.962245            Ohio        Columbus            Ohio
# 35  -97.534994  35.482309        Oklahoma   Oklahoma City        Oklahoma
# 36 -123.029159  44.931109          Oregon           Salem          Oregon
# 37  -76.875613  40.269789    Pennsylvania      Harrisburg    Pennsylvania
# 38  -71.422132  41.823550    Rhode Island      Providence    Rhode Island
# 39  -81.035000  34.000000  South Carolina        Columbia  South Carolina
# 40 -100.336378  44.367966    South Dakota          Pierre    South Dakota
# 41  -86.784000  36.165000       Tennessee       Nashville       Tennessee
# 42  -97.750000  30.266667           Texas          Austin           Texas
# 43 -111.892622  40.754700            Utah  Salt Lake City            Utah
# 44  -72.571940  44.266390         Vermont      Montpelier         Vermont
# 45  -77.460000  37.540000        Virginia        Richmond        Virginia
# 46 -122.893077  47.042418      Washington         Olympia      Washington
# 47  -81.633294  38.349497   West Virginia      Charleston   West Virginia
# 48  -89.384444  43.074722       Wisconsin         Madison       Wisconsin
# 49 -104.802042  41.145548         Wyoming        Cheyenne         Wyoming
#
#    geoCode  donald trump  scaled
# 0    US-AL            65     0.3
# 1    US-AK            58     0.1
# 2    US-AZ            69     0.5
# 3    US-AR            63     0.2
# 4    US-CA            73     0.6
# 5    US-CO            66     0.4
# 6    US-CT            79     0.8
# 7    US-DE            72     0.6
# 8    US-FL            72     0.6
# 9    US-GA            65     0.3
# 10   US-HI            56     0.0
# 11   US-ID            58     0.1
# 12   US-IL            75     0.7
# 13   US-IN            66     0.4
# 14   US-IA            71     0.5
# 15   US-KS            58     0.1
# 16   US-KY            65     0.3
# 17   US-LA            63     0.2
# 18   US-ME            72     0.6
# 19   US-MD            72     0.6
# 20   US-MA            80     0.9
# 21   US-MI            74     0.6
# 22   US-MN            73     0.6
# 23   US-MS            62     0.2
# 24   US-MO            66     0.4
# 25   US-MT            64     0.3
# 26   US-NE            67     0.4
# 27   US-NV            71     0.5
# 28   US-NH            73     0.6
# 29   US-NJ            84     1.0
# 30   US-NM            62     0.2
# 31   US-NY            81     0.9
# 32   US-NC            68     0.4
# 33   US-ND            66     0.4
# 34   US-OH            71     0.5
# 35   US-OK            60     0.1
# 36   US-OR            68     0.4
# 37   US-PA            79     0.8
# 38   US-RI            80     0.9
# 39   US-SC            63     0.2
# 40   US-SD            65     0.3
# 41   US-TN            66     0.4
# 42   US-TX            62     0.2
# 43   US-UT            56     0.0
# 44   US-VT            72     0.6
# 45   US-VA            70     0.5
# 46   US-WA            70     0.5
# 47   US-WV            69     0.5
# 48   US-WI            69     0.5
# 49   US-WY            56     0.0

# %%
import altair as alt
from vega_datasets import data

states = alt.topo_feature(data.us_10m.url, 'states')
state_fips = pd.read_csv('https://raw.githubusercontent.com/kjhealy/fips-codes/master/state_fips_master.csv')
geo_query = state_fips.merge(geo, left_on='state_name', right_on='state')

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

geo_query['scaled'] = scaler.fit_transform(geo_query[kw_list].values.reshape(-1,1)).round(1)
# US states background
map_plot = alt.Chart(states).mark_geoshape(
    stroke='black',
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(geo_query, 'fips', ['scaled'])
).encode(
    color=alt.Color('scaled:Q', scale=alt.Scale(scheme='lightmulti')),
    text='scaled:Q'
).properties(
    title='Breakdown by state',
    width=650,
    height=400
).project('albersUsa')

map_plot
# Out:
# alt.Chart(...)

# %%
from datapane import Report, Plot, Table, Markdown, Asset

r = [
    Markdown(f"""# Google Trend Analysis - {kw_list}
What are the Google trends for {kw_list}? Which US states are most interested? This script pulls data from the Google Trends API to find out...
"""),
    Table.create(geo),
    Plot.create(r_o_t_plot),
    Markdown(f"""
# Keyword geography interest

We can also query Google Trends to find which states search the most, and plot it on a map."""),
Plot.create(map_plot)
]

Report.create(*r)
# Out:
# 14:20:01 [INFO ] Uploading assets for Report
# 14:20:01 [INFO ] Uploading /var/folders/_x/188lgf3s507dygvl0b1l8rn40000gn/T/datapane-temp-h8z6ao0x.arrow
# 14:20:02 [INFO ] Uploading results_005.vl.json
# 14:20:05 [INFO ] Uploading results_006.vl.json
#         <iframe
#             width="600"
#             height="500"
#             src="https://acme.datapane.com/reports/j3LwxAQ/embed/?accesstoken=0d139abd133d9e021f6d7ab3665ad2621649f551"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
